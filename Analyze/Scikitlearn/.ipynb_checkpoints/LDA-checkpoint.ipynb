# %%
# !pip install pyLDAvis

# %%
import pyLDAvis
import pyLDAvis.sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
pyLDAvis.enable_notebook()

# %%
import csv

with open('../kwlist.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    mydoc = list(tuple(rec) for rec in reader)

# %%
docraws=[]
for rec in mydoc:
    docraws.append(rec[1])

# %%
vect = CountVectorizer()

# %%
myMatrix = vect.fit_transform(docraws)

# %%
myMatrix.shape
# Out:
# (410958, 435274)

# %%
LDA = LatentDirichletAllocation(n_topics=10, random_state=0)

# %%
LDA.fit(myMatrix)
# Out:
# C:\python\lib\site-packages\sklearn\decomposition\online_lda.py:508: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7, learning_method=None,
#              learning_offset=10.0, max_doc_update_iter=100, max_iter=10,
#              mean_change_tol=0.001, n_jobs=1, n_topics=10, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
pyLDAvis.sklearn.prepare(LDA, myMatrix, vect, mds='tsne')
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics           x           y
# topic
# 1      11.441442        1       1 -102.395062   99.610345
# 4      11.124258        1       2  -75.658246 -201.962847
# 3      10.774394        1       3   -4.624645  -25.661757
# 2       9.896766        1       4  125.279873 -164.664258
# 9       9.796769        1       5 -176.976913  -28.927025
# 7       9.555042        1       6  157.638019  -17.482868
# 0       9.517754        1       7  106.345405  114.905086
# 5       9.473880        1       8  -11.339987  199.070629
# 6       9.401532        1       9   34.750087  332.231214
# 8       9.018164        1      10    2.091540 -347.986841, topic_info=       Category          Freq        Term         Total  loglift  logprob
# term
# 290705  Default  11348.000000     percent  11348.000000  30.0000  30.0000
# 395008  Default   8644.000000       trump   8644.000000  29.0000  29.0000
# 298282  Default   6794.000000     polouse   6794.000000  28.0000  28.0000
# 72326   Default   5785.000000       china   5785.000000  27.0000  27.0000
# 35445   Default   5389.000000        bank   5389.000000  26.0000  26.0000
# 214752  Default   5239.000000      league   5239.000000  25.0000  25.0000
# 116718  Default   4441.000000     england   4441.000000  24.0000  24.0000
# 276194  Default   4087.000000     olympic   4087.000000  23.0000  23.0000
# 67781   Default   4264.000000        cent   4264.000000  22.0000  22.0000
# 77086   Default   4068.000000        club   4068.000000  21.0000  21.0000
# 89393   Default   3679.000000         cup   3679.000000  20.0000  20.0000
# 372514  Default   3505.000000      syrium   3505.000000  19.0000  19.0000
# 271181  Default   3729.000000       obama   3729.000000  18.0000  18.0000
# 76622   Default   3708.000000     clinton   3708.000000  17.0000  17.0000
# 319574  Default   3637.000000  republican   3637.000000  16.0000  16.0000
# 372406  Default   3376.000000      syrian   3376.000000  15.0000  15.0000
# 313511  Default   3228.000000        rate   3228.000000  14.0000  14.0000
# 184028  Default   3153.000000        iran   3153.000000  13.0000  13.0000
# 120214  Default   3139.000000        euro   3139.000000  12.0000  12.0000
# 85826   Default   3329.000000       court   3329.000000  11.0000  11.0000
# 303352  Default   2944.000000       price   2944.000000  10.0000  10.0000
# 30332   Default   2928.000000  australium   2928.000000   9.0000   9.0000
# 178954  Default   3173.000000       index   3173.000000   8.0000   8.0000
# 71008   Default   2910.000000     chelsea   2910.000000   7.0000   7.0000
# 5772        1  0.999555       africa
# 8094        7  0.999151          air
# 8171        9  0.999256     aircraft
# 8272        4  0.999444      airline
# 8348        5  0.999191      airport
# 10540       4  0.999227       aleppo
# 19525       5  0.313764       animal
# 19525       7  0.685366       animal
# 22488       7  0.999436          app
# 22654       6  0.999501        apple
# 23331       9  0.999173      arabium
# 25522       3  0.999139       arrest
# 25704       2  0.999443      arsenal
# 29215       4  0.999783       attack
# 30260       8  0.999606   australian
# 30332       8  0.999606   australium
# 31372       8  0.999550        award
# 32531       1  0.999509         baby
# 34578       2  0.999251         ball
# 35346       4  0.999560   bangladesh
# 35445       8  0.999815         bank
# 36220       2  0.999348    barcelona
# 38827       5  0.999256        beach
# 40658       6  0.999590      beijing
# 45465       5  0.999439       bikini
# ...       ...       ...          ...
# 392026      6  0.999779        trade
# 392390      9  0.999784        train
# 393810      7  0.999516        trial
# 395008      1  0.999947        trump
# 396689      3  0.999829       turkey
# 396745      3  0.999449      turkish
# 399502      4  0.999699      ukraine
# 402146      6  0.999203        unite
# 406104      2  0.999562          van
# 407340      3  0.999710      vehicle
# 408834      4  0.999034       victim
# 409448      4  0.998864        villa
# 410156      8  0.999067         viru
# 411654      1  0.779548         vote
# 411654      8  0.220411         vote
# 411709      8  0.999222        voter
# 413141      6  0.999474         wale
# 415067      4  0.999303        water
# 418158     10  0.999611         west
# 421328      7  0.999215      william
# 421628      9  0.999186          win
# 423744      1  0.717028        woman
# 423744      4  0.282853        woman
# 424408     10  0.998934       worker
# 429192      9  0.999496        yeman
# 429262      1  0.999289          yen
# 429674      6  0.999439        yield
# 430331      8  0.998659         york
# 432670      2  0.999269      zealand
# 433780      8  0.999557         zika
#
# [341 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 5, 4, 3, 10, 8, 1, 6, 7, 9])

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
n_top_words = 15

# %%
print_top_words(LDA, vect.get_feature_names(), n_top_words)
# Out:
# Topic #0:
# city sale sentence football fire feed william mexico park trial island abuse billion child quarter
# Topic #1:
# percent trump cent obama clinton republican court index russium oil russian party tax woman stock
# Topic #2:
# syrium syrian euro pakistan attack islamic rebel labmy ukraine ireland team water airline afghanistan bomb
# Topic #3:
# polouse officer car test turkey shoot japan refugee madrid health crash patient turkish fund prosecutor
# Topic #4:
# league club player liverpool nuclear drug arsenal manchester migrant black leicester cricket greece barcelona zealand
# Topic #5:
# bank australium student film australian cameron tournament award dog nigerium loan melbourne council law viru
# Topic #6:
# cup iran dres race saudi yeman child train plane italy million poll militant prince iranian
# Topic #7:
# china england rate price goal israel game chinese israeli palestinian trade score unite dollar actres
# Topic #8:
# korea market britain season north coach girl brexit korean kim bill brazil south bond murder
# Topic #9:
# olympic chelsea school rio golf airport model passenger food driver beach scotland french gold hong

# %%
LDA.components_.shape
# Out:
# (10, 435274)

# %%
type(LDA)
# Out:
# sklearn.decomposition.online_lda.LatentDirichletAllocation
