# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install lxml

# %%
from bs4 import BeautifulSoup
import lxml
import requests as r
import json
import datetime as d
# from datetime import date as d
# from datetime import timedelta as td

# %%
#Get urls list of x days from today ... range(-x,0)
def getArticlesList(nDays):

    articlesList = []

    for delta in range(0, nDays):

        date = (d.date.today() - d.timedelta(delta)).strftime('%Y/%m/%d')
        daily_url = 'http://www.nytimes.com/indexes/%s/todayspaper/index.html'%(date)

        res = r.get(daily_url)
        res.encoding = 'unicode'
        soup = BeautifulSoup(res.text, 'lxml')
        articles = soup.select('.aColumn h6 a') + soup.select('.aColumn h3 a') + soup.select('#SpanABMiddleRegion h6 a')

        for article in articles:
            art_dict = {}

            art_dict['title'] = article.text.strip()
            art_dict['date'] = date
            art_dict['source'] = 'NYT'
            art_dict['url'] = article['href']
            articlesList.append(art_dict)

    return articlesList

# %%
getArticlesList(1)
# Out:
# [{'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Climate Change Reroutes a Yukon River in a Geological Instant',
#   'url': 'https://www.nytimes.com/2017/04/17/science/climate-change-glacier-yukon-river.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Prince Harry Says He Sought Counseling Over His Mother’s Death',
#   'url': 'https://www.nytimes.com/2017/04/17/world/europe/uk-prince-harry-death-princess-diana.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Brooklyn Walkway to Reopen, With Less Bounce in Your Steps',
#   'url': 'https://www.nytimes.com/2017/04/17/nyregion/brooklyn-squibb-park-bridge-reopening.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Steve Ballmer Serves Up a Fascinating Data Trove',
#   'url': 'https://www.nytimes.com/2017/04/17/business/dealbook/steve-ballmer-serves-up-a-fascinating-data-trove.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Review: A Star Is Born (and Born and Born) in ‘Groundhog Day’',
#   'url': 'https://www.nytimes.com/2017/04/17/theater/groundhog-day-review-andy-karl.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trump Presides Over His First White House Easter Egg Roll',
#   'url': 'https://www.nytimes.com/2017/04/17/us/politics/white-house-easter-egg-roll-trump.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Monday’s Arkansas Execution Halted by State Justices',
#   'url': 'https://www.nytimes.com/2017/04/17/us/mondays-arkansas-execution-halted-by-state-justices.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'How Prince Concealed His Addiction: Aspirin Bottles of Opiates',
#   'url': 'https://www.nytimes.com/2017/04/17/arts/music/prince-opioid-death.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Bitter Fight Behind Him, Justice Gorsuch Starts Day With Relish',
#   'url': 'https://www.nytimes.com/2017/04/17/us/politics/justice-neil-gorsuch-supreme-court.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'First Woman to Enter Boston Marathon Runs It Again, 50 Years Later',
#   'url': 'https://www.nytimes.com/2017/04/17/sports/boston-marathon-kathrine-switzer.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trump’s Unreleased Taxes Threaten Yet Another Campaign Promise',
#   'url': 'https://www.nytimes.com/2017/04/17/us/politics/tax-code-overhaul-trump.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'It’s France’s Turn to Worry About Election Meddling by Russia',
#   'url': 'https://www.nytimes.com/2017/04/17/world/europe/french-election-russia.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'In Supporting Erdogan, Turks Cite Economic and Religious Gains',
#   'url': 'https://www.nytimes.com/2017/04/17/world/europe/turkey-referendum-erdogan.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'A Murder Posted on Facebook Prompts Outrage and Questions Over Responsibility',
#   'url': 'https://www.nytimes.com/2017/04/17/technology/facebook-live-murder-broadcast.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trump Voters in a Swing District Wonder When the ‘Winning’ Will Start',
#   'url': 'https://www.nytimes.com/2017/04/17/us/politics/trump-voters-swing-state.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Chris Christie Heads for the Door, Minus the Earlier Throngs',
#   'url': 'https://www.nytimes.com/2017/04/17/nyregion/chris-christie-new-jersey.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Pence Talks Tough on North Korea, but U.S. Stops Short of Drawing Red Line',
#   'url': 'https://www.nytimes.com/2017/04/17/world/asia/trump-north-korea-nuclear-us-talks.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'MEJORADA DEL CAMPO Journal: Ex-Monk Erects a ‘Cathedral of Faith’ Brick by Brick, and Mostly Alone',
#   'url': 'https://www.nytimes.com/2017/04/17/world/europe/mejorada-del-campo-spain-justo-gallego-cathedral.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Over 1,000 Palestinian Prisoners in Israel Stage Hunger Strike',
#   'url': 'https://www.nytimes.com/2017/04/17/world/middleeast/marwan-barghouti-hunger-strike-israel.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'A Former Spokesman for the Pakistani Taliban Surrenders',
#   'url': 'https://www.nytimes.com/2017/04/17/world/asia/spokesman-pakistani-taliban-surrenders.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Climate Change Reroutes a Yukon River in a Geological Instant',
#   'url': 'https://www.nytimes.com/2017/04/17/science/climate-change-glacier-yukon-river.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Tensions in Indonesian Capital Run High as Election Nears',
#   'url': 'https://www.nytimes.com/2017/04/17/world/asia/jakarta-election-purnama-ahok-basuki.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'The Interpreter: The North Korea Paradox: Why There Are No Good Options on Nuclear Arms',
#   'url': 'https://www.nytimes.com/2017/04/17/world/asia/north-korea-nuclear-weapons-missiles-sanctions.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Pence Talks Tough on North Korea, but U.S. Stops Short of Drawing Red Line',
#   'url': 'https://www.nytimes.com/2017/04/17/world/asia/trump-north-korea-nuclear-us-talks.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Park Geun-hye, Ousted President of South Korea, Is Formally Indicted',
#   'url': 'https://www.nytimes.com/2017/04/17/world/asia/park-geun-hye-south-korea-president-indictment.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'In Afghanistan, ‘I Feel Like a Divorced Woman Is Up for Grabs’',
#   'url': 'https://www.nytimes.com/2017/04/17/world/asia/afghan-women-divorce.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Prince Harry Says He Sought Counseling Over His Mother’s Death',
#   'url': 'https://www.nytimes.com/2017/04/17/world/europe/uk-prince-harry-death-princess-diana.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Turkey Vote Could Mean the End of a Courtship to Join the E.U.',
#   'url': 'https://www.nytimes.com/2017/04/17/world/europe/turkey-eu-referendum.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trump Congratulates Erdogan on Vote Amplifying His Power',
#   'url': 'https://www.nytimes.com/2017/04/17/us/politics/trump-erdogan-turkey-referendum.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trump Presides Over His First White House Easter Egg Roll',
#   'url': 'https://www.nytimes.com/2017/04/17/us/politics/white-house-easter-egg-roll-trump.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'How Prince Concealed His Addiction: Aspirin Bottles of Opiates',
#   'url': 'https://www.nytimes.com/2017/04/17/arts/music/prince-opioid-death.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Monday’s Arkansas Execution Halted by State Justices',
#   'url': 'https://www.nytimes.com/2017/04/17/us/mondays-arkansas-execution-halted-by-state-justices.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Why Gorsuch May Not Be So Genteel on the Bench',
#   'url': 'https://www.nytimes.com/2017/04/17/us/politics/why-gorsuch-may-not-be-so-genteel-on-the-bench.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Bitter Fight Behind Him, Justice Gorsuch Starts Day With Relish',
#   'url': 'https://www.nytimes.com/2017/04/17/us/politics/justice-neil-gorsuch-supreme-court.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Spicer Argues That More Public Disclosure Is Unnecessary, Even Harmful',
#   'url': 'https://www.nytimes.com/2017/04/17/us/politics/spicer-argues-that-more-public-disclosure-is-unnecessary-even-harmful.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Watchdog Group Expands Lawsuit Against Trump',
#   'url': 'https://www.nytimes.com/2017/04/18/us/politics/trump-crew-lawsuit-constitution.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Planned Trump Order Will Discourage Hiring of Low-Wage Foreign Workers',
#   'url': 'https://www.nytimes.com/2017/04/18/us/politics/trump-executive-order-h1b-visas-technology-workers.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Christopher Morahan, a Producer and Director of ‘The Jewel in the Crown,’ Dies at 87',
#   'url': 'https://www.nytimes.com/2017/04/14/arts/television/christopher-morahan-dead-directed-jewel-in-the-crown.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Clifton James, Who Played a Sheriff in 2 Bond Films, Dies at 96',
#   'url': 'https://www.nytimes.com/2017/04/16/movies/clifton-james-who-played-a-sheriff-in-2-bond-films-dies-at-96.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Editorial: Democracy Loses in Turkey',
#   'url': 'https://www.nytimes.com/2017/04/17/opinion/democracy-loses-in-turkey.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Letters: Let Trump Deliver on Mass Transit',
#   'url': 'https://www.nytimes.com/2017/04/17/opinion/let-trump-deliver-on-mass-transit.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Letters: Planned Parenthood Funding',
#   'url': 'https://www.nytimes.com/2017/04/17/opinion/planned-parenthood-funding.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Letter: Trump and AIDS Relief',
#   'url': 'https://www.nytimes.com/2017/04/17/opinion/trump-and-aids-relief.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Brooklyn Walkway to Reopen, With Less Bounce in Your Steps',
#   'url': 'https://www.nytimes.com/2017/04/17/nyregion/brooklyn-squibb-park-bridge-reopening.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'New York Moves to Require Uber to Provide Tipping Option in Its App',
#   'url': 'https://www.nytimes.com/2017/04/17/nyregion/new-york-city-uber-tipping-app.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'With More Tipping Options Comes More Confusion',
#   'url': 'https://www.nytimes.com/2017/04/17/nyregion/tipping-in-new-york.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Cuomo Promotes Chief of Staff, Melissa DeRosa, to Be His Secretary',
#   'url': 'https://www.nytimes.com/2017/04/17/nyregion/cuomo-promotes-chief-of-staff-melissa-derosa-to-be-his-secretary.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Guilty Verdict in Murder Case Set Aside at Request of Bronx District Attorney',
#   'url': 'https://www.nytimes.com/2017/04/17/nyregion/steven-odiase-murder-conviction-new-trial.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Emerging Markets Are Bouncing Back From a Six-Year Slowdown',
#   'url': 'https://www.nytimes.com/2017/04/17/business/dealbook/turkey-referendum-emerging-markets.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Steve Ballmer Serves Up a Fascinating Data Trove',
#   'url': 'https://www.nytimes.com/2017/04/17/business/dealbook/steve-ballmer-serves-up-a-fascinating-data-trove.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'With a Hollywood Writers’ Strike Looming, Here’s What to Know',
#   'url': 'https://www.nytimes.com/2017/04/17/business/media/with-a-hollywood-writers-strike-looming-heres-what-to-know.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'A McDonald’s Ad That Never Mentions the Name McDonald’s',
#   'url': 'https://www.nytimes.com/2017/04/17/business/media/mcdonalds-ads-mindy-kaling.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'BP Gas Leak Is Under Control in Alaska Oil Field',
#   'url': 'https://www.nytimes.com/2017/04/17/business/energy-environment/bp-alaska-oil-well-gas-leak.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Silver Lake Raises $15 Billion Fund for New Tech Deals',
#   'url': 'https://www.nytimes.com/2017/04/17/business/dealbook/silver-lake-raises-15-billion-fund-for-new-tech-deals.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Arconic C.E.O. Ousted After Sending Unauthorized Letter to Hedge Fund',
#   'url': 'https://www.nytimes.com/2017/04/17/business/dealbook/alcoa-arconic-klaus-kleinfeld-elliott-management.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Overbooked: Stories of Airline Agony (and Some Rewards)',
#   'url': 'https://www.nytimes.com/2017/04/17/business/overbooked-airline-passengers-stories.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'The Upshot: How Much Would You Put Up With to Avoid United Airlines?',
#   'url': 'https://www.nytimes.com/2017/04/17/upshot/how-much-would-people-put-up-with-to-avoid-united-airlines.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'On Pro Basketball: Camp Lockdown? Rockets’ Patrick Beverley Puts On a Clinic',
#   'url': 'https://www.nytimes.com/2017/04/17/sports/basketball/patrick-beverley-russell-westbrook-nba-playoffs.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'In America’s Cup Waters, a Robot Takes On an Invasion of Lionfish',
#   'url': 'https://www.nytimes.com/2017/04/17/sports/sailing/americas-cup-bermuda-lionfish.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Baseball’s Data Revolution Is Elevating Defensive Dynamos',
#   'url': 'https://www.nytimes.com/2017/04/17/sports/baseball/baseballs-data-revolution-is-elevating-defensive-dynamos.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Yankees 7, White Sox 4: Yankees’ Mishmash Lineup Produces Common Result: Another Win',
#   'url': 'https://www.nytimes.com/2017/04/17/sports/baseball/new-york-yankees-chicago-white-sox.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Boston Marathon 2017: Kenyans Sweep the Main Events',
#   'url': 'https://www.nytimes.com/2017/04/17/sports/boston-marathon-2017-kenyans-sweep-the-main-events.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'First Woman to Enter Boston Marathon Runs It Again, 50 Years Later',
#   'url': 'https://www.nytimes.com/2017/04/17/sports/boston-marathon-kathrine-switzer.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Mats Zuccarello Urges Rangers to Show Some Desperation in Game 4',
#   'url': 'https://www.nytimes.com/2017/04/17/sports/hockey/rangers-canadiens-nhl-playoffs.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Cavaliers and Spurs Hold On, Extending Their Playoff Leads',
#   'url': 'https://www.nytimes.com/2017/04/17/sports/basketball/cavaliers-beat-pacers-game-2.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Sports Briefing: Maple Leafs Rally and Defeat Capitals in Overtime',
#   'url': 'https://www.nytimes.com/2017/04/18/sports/maple-leafs-capitals-game-3.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Review: A Star Is Born (and Born and Born) in ‘Groundhog Day’',
#   'url': 'https://www.nytimes.com/2017/04/17/theater/groundhog-day-review-andy-karl.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': "Critic's Notebook: How YouTube’s Shifting Algorithms Hurt Independent Media",
#   'url': 'https://www.nytimes.com/2017/04/17/arts/youtube-broadcasters-algorithm-ads.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Books of The Times: ‘Shattered’ Charts Hillary Clinton’s Course Into the Iceberg',
#   'url': 'https://www.nytimes.com/2017/04/17/books/shattered-charts-hillary-clintons-course-into-the-iceberg.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Then What Happened? The Checkered History of Stage Sequels',
#   'url': 'https://www.nytimes.com/2017/04/17/theater/then-what-happened-the-checkered-history-of-stage-sequels.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Review: ‘It Will All Work Out’ Banishes Worry With Razzle-Dazzle',
#   'url': 'https://www.nytimes.com/2017/04/17/theater/it-will-all-work-out-review.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Disney’s ‘Frozen’ Musical Casts Its Princesses',
#   'url': 'https://www.nytimes.com/2017/04/17/theater/disneys-frozen-musical-casts-its-princesses.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'The Chainsmokers Prove They’re a Hit on the Album Chart, Too',
#   'url': 'https://www.nytimes.com/2017/04/17/arts/music/chainsmokers-memories-billboard-chart.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'An Atlanta Theater Faces Criticism for Gay Versions of Bible Stories',
#   'url': 'https://www.nytimes.com/2017/04/17/theater/out-front-theater-company-criticism-for-gay-versions-of-bible-the-most-fabulous-story-ever-told.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'A Word With: After a Half-Century in Music, Clive Davis Is Still in Love',
#   'url': 'https://www.nytimes.com/2017/04/17/arts/music/clive-davis-soundtrack-of-our-lives-film-interview.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Review: 3 Anniversary Programs Look at Los Angeles in Flames',
#   'url': 'https://www.nytimes.com/2017/04/17/arts/television/los-angeles-riots-tv-documentaries-25th-anniversary.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'What’s on TV Tuesday: ‘Pretty Little Liars’ and ‘Frontline’',
#   'url': 'https://www.nytimes.com/2017/04/18/arts/television/whats-on-tv-tuesday-pretty-little-liars-and-frontline.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'A California Court for Young Adults Calls on Science',
#   'url': 'https://www.nytimes.com/2017/04/17/health/young-adult-court-san-francisco-california-neuroscience.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Scientists and Activists Look Beyond the March for Science',
#   'url': 'https://www.nytimes.com/2017/04/17/science/march-for-science-april-22.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': '6 Things I Learned About Ulcers',
#   'url': 'https://www.nytimes.com/2017/04/13/well/eat/6-things-i-learned-about-ulcers.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trilobites: Photos of Jupiter From NASA Spacecraft, Both Near and Far',
#   'url': 'https://www.nytimes.com/2017/04/07/science/jupiter-photos-hubble-telescope-juno-nasa.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trilobites: A Lizard With Scales That Behave Like a Computer Simulation',
#   'url': 'https://www.nytimes.com/2017/04/12/science/ocellated-lizards-scales-cellular-automata.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trilobites: Saber-Toothed Cats Paid a Stiff Price for Lunch',
#   'url': 'https://www.nytimes.com/2017/04/12/science/saber-toothed-cats-dire-wolf-hunting-injuries.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trilobites: Valiant in Battle, These Ants Rescue Their Wounded',
#   'url': 'https://www.nytimes.com/2017/04/12/science/ants-help-injured-ants-home.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Do Your Shoelaces Keep Coming Undone? Engineers Explain Why',
#   'url': 'https://www.nytimes.com/2017/04/13/science/why-shoelaces-undone-untied.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'An Ice Scientist’s Worst Nightmare',
#   'url': 'https://www.nytimes.com/2017/04/11/climate/ice-cores-melted-freezer-alberta-canada.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Global Health: In a Dragon’s Blood, Scientists Discover a Potential Antibiotic',
#   'url': 'https://www.nytimes.com/2017/04/17/health/komodo-dragon-blood-antibiotics.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Q&A: Avian Housing Wars: Competition for Nesting Spots',
#   'url': 'https://www.nytimes.com/2017/04/17/science/birds-nests-birdhouses-competition.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Take a Number: Ranks of Scientists Aging Faster Than Other Workers',
#   'url': 'https://www.nytimes.com/2017/04/17/science/ranks-of-scientists-aging-faster-than-other-workers.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Out There: ‘Genius’ Unravels the Mysteries of Einstein’s Universe',
#   'url': 'https://www.nytimes.com/2017/04/17/science/albert-einstein-genius-national-geographic-channel.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'The March for Science: Why Some Are Going, and Some Will Sit Out',
#   'url': 'https://www.nytimes.com/2017/04/17/science/march-for-science-voices.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'An Hour of Running May Add 7 Hours to Your Life',
#   'url': 'https://www.nytimes.com/2017/04/12/well/move/an-hour-of-running-may-add-seven-hours-to-your-life.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Is Chewing Gum Good for Toddlers? Or Anyone?',
#   'url': 'https://www.nytimes.com/2017/04/05/well/family/is-chewing-gum-good-for-toddlers-or-anyone.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Heart Risks in Midlife Tied to Brain Plaques of Alzheimer’s',
#   'url': 'https://www.nytimes.com/2017/04/12/well/mind/heart-risks-in-midlife-tied-to-brain-plaques-of-alzheimers.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Trans Fat Bans Tied to Fewer Heart Attacks and Strokes',
#   'url': 'https://www.nytimes.com/2017/04/12/well/eat/trans-fat-bans-tied-to-fewer-heart-attacks-and-strokes.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Marathons: An Especially Bad Day for a Heart Attack',
#   'url': 'https://www.nytimes.com/2017/04/13/well/live/marathons-an-especially-bad-day-for-a-heart-attack.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'The Cost of Not Taking Your Medicine',
#   'url': 'https://www.nytimes.com/2017/04/17/well/the-cost-of-not-taking-your-medicine.html?ref=todayspaper'},
#  {'date': '2017/04/18',
#   'source': 'NYT',
#   'title': 'Corrections: April 18, 2017',
#   'url': 'https://www.nytimes.com/2017/04/17/pageoneplus/corrections-april-18-2017.html?ref=todayspaper'}]

# %%
def getArticle(art_url):

    art_dict = {}

    res = r.get(art_url)
    res.encoding = 'unicode'
    soup = BeautifulSoup(res.text, 'lxml')
    art_date = art_date = soup.select('.dateline')[0]['content'].split('T')[0]
    art_title = soup.select('#headline')[0].text
    art_body = soup.select(
        '.story-body-supplemental .story-body-text.story-content')

    art_paras = {}
    for numPara in range(len(art_body)):
        art_paras[numPara + 1] = art_body[numPara].text.strip()

    art_dict['title'] = art_title
    art_dict['date'] = art_date
    art_dict['source'] = 'NYT'
    art_dict['url'] = art_url
    art_dict['content'] = art_paras

    return art_dict

# %%
collection = []
for article in getArticlesList(1)[0:5]:
    collection.append(getArticle(article['url']))
    
print(len(collection))
jsonOut(collection)
# Out:
# 5
# 20170418_NYT_output.json has been created!

# %%
def jsonOut(inputList):
    src = inputList[0]['source']
    day = d.date.today().strftime('%Y%m%d')
    filename = '{}_{}_output.json'.format(day, src)
    with open(filename, 'w') as f:
        json.dump(inputList, f)
        f.close()
    print(filename + ' has been created!')
