# %%
import datetime as d
import sys
import requests as r

import getCNN as gc
import getNYT as gn
import getBBC as gb
import toJsonFile as tj

# %%
# CNN test
cats = gc.getCatLinks()

for cat in cats:
    print(gc.getArticlesList(cat))
# Out:
# [{'title': 'Manhunt widens for Facebook murder suspect', 'url': 'http://edition.cnn.com/2017/04/17/us/cleveland-facebook-homicide-video/index.html'}, {'title': 'Facebook shooting victim was walking home after Easter meal', 'url': 'http://edition.cnn.com/2017/04/17/us/facebook-homicide-victim-trnd/index.html'}, {'title': 'Why Facebook still struggles to pull down murder videos quickly', 'url': 'http://money.cnn.com/2017/04/17/technology/facebook-safety-protocol/index.html'}, {'title': 'Cops: Facebook shooting suspect may have crossed state lines', 'url': 'http://edition.cnn.com/videos/justice/2017/04/17/cleveland-facebook-killing-suspect-manhunt-expands-outside-ohio-es.cnn'}, {'title': 'Opinion: Make it a crime to show killing on Facebook', 'url': 'http://edition.cnn.com/2017/04/17/opinions/facebook-shooting-death-cevallos/index.html'}, {'title': 'Prince documents unsealed: No meds in home were prescribed to him', 'url': 'http://edition.cnn.com/2017/04/17/health/prince-death-investiga
# ...
