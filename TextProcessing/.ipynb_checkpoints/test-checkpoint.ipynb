# %%
# !pip install textblob
# !python -m textblob.download_corpora

# %%
import json
import string
import re
import pymongo

# from pymongo import MongoClient
from textblob import TextBlob
from textblob import Word
from nltk.corpus import stopwords
from collections import Counter
from pprint import pprint

# %%
stopwords = stopwords.words('English')
stoplist = string.punctuation.split() + stopwords

# print(stoplist)

# %%
with open('news.news.json',encoding='utf8') as f:
    texts = json.load(f)

contents = texts['content']

# pprint(contents)
# type(contents)

# %%
# Get connection to MongoDB@10.120.28.55
try:
    client = pymongo.MongoClient('10.120.28.55', 27017)
    db = client['news']
    collection_read = db['news']
    collection_write = db['word_sict']
    
except:
    print('Cannot connect to MongoDB server!')

# %%
getArt = collection_read.find_one()

# %%
type(c['content'])
# Out:
# dict

# %%
print(c['_id'])
# Out:
# 58f831913f3dfa243452d7ee

# %%
words_dict = {}
newdict = updateWordsDict(getArt, words_dict)

# %%
pprint(newdict)
# Out:
# {'accord': {'count': 3,
#             'src': {'58f831913f3dfa243452d7ee_1',
#                     '58f831913f3dfa243452d7ee_11',
#                     '58f831913f3dfa243452d7ee_16'}},
#  'account': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_15'}},
#  'actively': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'actor': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'add': {'count': 2,
#          'src': {'58f831913f3dfa243452d7ee_10', '58f831913f3dfa243452d7ee_19'}},
#  'administration': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_2'}},
#  'advertise': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'affair': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'affect': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'affection': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_19'}},
#  'afternoon': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'agency': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_3'}},
#  'aim': {'count': 2,
#          'src': {'58f831913f3dfa243452d7ee_3', '58f831913f3dfa243452d7ee_5'}},
#  'air': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'also': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'appear': {'count': 4,
#             'src': {'58f831913f3dfa243452d7ee_12',
#                     '58f831913f3dfa243452d7ee_14',
#                     '58f831913f3dfa243452d7ee_5',
#                     '58f831913f3dfa243452d7ee_7'}},
#  'apply': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'assign': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'association': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'attention': {'count': 2,
#                'src': {'58f831913f3dfa243452d7ee_12',
#                        '58f831913f3dfa243452d7ee_16'}},
#  'attract': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'avoid': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'back': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_5'}},
#  'ban': {'count': 4,
#          'src': {'58f831913f3dfa243452d7ee_11',
#                  '58f831913f3dfa243452d7ee_2',
#                  '58f831913f3dfa243452d7ee_3',
#                  '58f831913f3dfa243452d7ee_4'}},
#  'base': {'count': 2,
#           'src': {'58f831913f3dfa243452d7ee_6', '58f831913f3dfa243452d7ee_8'}},
#  'basketball': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'become': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_9'}},
#  'beijing': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_8'}},
#  'birth': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_9'}},
#  'book': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'broadcast': {'count': 5,
#                'src': {'58f831913f3dfa243452d7ee_1',
#                        '58f831913f3dfa243452d7ee_12',
#                        '58f831913f3dfa243452d7ee_14',
#                        '58f831913f3dfa243452d7ee_8'}},
#  'broader': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'call': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'celebrities': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'celebrity': {'count': 7,
#                'src': {'58f831913f3dfa243452d7ee_11',
#                        '58f831913f3dfa243452d7ee_14',
#                        '58f831913f3dfa243452d7ee_2',
#                        '58f831913f3dfa243452d7ee_5',
#                        '58f831913f3dfa243452d7ee_6',
#                        '58f831913f3dfa243452d7ee_9'}},
#  'censor': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'child': {'count': 9,
#            'src': {'58f831913f3dfa243452d7ee_1',
#                    '58f831913f3dfa243452d7ee_11',
#                    '58f831913f3dfa243452d7ee_2',
#                    '58f831913f3dfa243452d7ee_3',
#                    '58f831913f3dfa243452d7ee_5',
#                    '58f831913f3dfa243452d7ee_6',
#                    '58f831913f3dfa243452d7ee_7',
#                    '58f831913f3dfa243452d7ee_9'}},
#  'childhood': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_10'}},
#  'china': {'count': 3,
#            'src': {'58f831913f3dfa243452d7ee_1',
#                    '58f831913f3dfa243452d7ee_12',
#                    '58f831913f3dfa243452d7ee_6'}},
#  'chinese': {'count': 2,
#              'src': {'58f831913f3dfa243452d7ee_1',
#                      '58f831913f3dfa243452d7ee_11'}},
#  'clas': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_10'}},
#  'class': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_8'}},
#  'close': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'comedian': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'commentator': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_18'}},
#  'complete': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'comprehensive': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'continue': {'count': 2,
#               'src': {'58f831913f3dfa243452d7ee_4',
#                       '58f831913f3dfa243452d7ee_9'}},
#  'contribute': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_20'}},
#  'cook': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'core': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_18'}},
#  'could': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_10'}},
#  'cute': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_1'}},
#  'dad': {'count': 4,
#          'src': {'58f831913f3dfa243452d7ee_17',
#                  '58f831913f3dfa243452d7ee_5',
#                  '58f831913f3dfa243452d7ee_6'}},
#  'daily': {'count': 2,
#            'src': {'58f831913f3dfa243452d7ee_14',
#                    '58f831913f3dfa243452d7ee_18'}},
#  'deal': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'deep': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_19'}},
#  'depiction': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'desire': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_19'}},
#  'destination': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'difference': {'count': 2,
#                 'src': {'58f831913f3dfa243452d7ee_10',
#                         '58f831913f3dfa243452d7ee_8'}},
#  'display': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_19'}},
#  'document': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'effort': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'end': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'endorsement': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'energy': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'episode': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'especially': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_2'}},
#  'even': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_15'}},
#  'exclude': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_13'}},
#  'expert': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_11',
#                     '58f831913f3dfa243452d7ee_5'}},
#  'extra': {'count': 2, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'extramarital': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'fame': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_3'}},
#  'family': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_18'}},
#  'fast': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'father': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'feature': {'count': 3,
#              'src': {'58f831913f3dfa243452d7ee_1',
#                      '58f831913f3dfa243452d7ee_11',
#                      '58f831913f3dfa243452d7ee_5'}},
#  'film': {'count': 2,
#           'src': {'58f831913f3dfa243452d7ee_2', '58f831913f3dfa243452d7ee_6'}},
#  'first': {'count': 2,
#            'src': {'58f831913f3dfa243452d7ee_3', '58f831913f3dfa243452d7ee_6'}},
#  'five': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'focu': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'focus': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'follow': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_14',
#                     '58f831913f3dfa243452d7ee_6'}},
#  'foreign': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'former': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'fox': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'frequent': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'future': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'gay': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'general': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'giggly': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_1'}},
#  'go': {'count': 4,
#         'src': {'58f831913f3dfa243452d7ee_13',
#                 '58f831913f3dfa243452d7ee_17',
#                 '58f831913f3dfa243452d7ee_5',
#                 '58f831913f3dfa243452d7ee_6'}},
#  'government': {'count': 4,
#                 'src': {'58f831913f3dfa243452d7ee_12',
#                         '58f831913f3dfa243452d7ee_17',
#                         '58f831913f3dfa243452d7ee_18',
#                         '58f831913f3dfa243452d7ee_4'}},
#  'grow': {'count': 2,
#           'src': {'58f831913f3dfa243452d7ee_17', '58f831913f3dfa243452d7ee_4'}},
#  'guideline': {'count': 7,
#                'src': {'58f831913f3dfa243452d7ee_11',
#                        '58f831913f3dfa243452d7ee_12',
#                        '58f831913f3dfa243452d7ee_13',
#                        '58f831913f3dfa243452d7ee_2',
#                        '58f831913f3dfa243452d7ee_3',
#                        '58f831913f3dfa243452d7ee_5',
#                        '58f831913f3dfa243452d7ee_8'}},
#  'halt': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'heartwarming': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_19'}},
#  'hint': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'home': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_19'}},
#  'hostility': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_17'}},
#  'hugely': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_14',
#                     '58f831913f3dfa243452d7ee_5'}},
#  'hunan': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_5'}},
#  'ignite': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_19'}},
#  'image': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'impact': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_10'}},
#  'import': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'include': {'count': 3,
#              'src': {'58f831913f3dfa243452d7ee_11',
#                      '58f831913f3dfa243452d7ee_4'}},
#  'incorporate': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'independent': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'industry': {'count': 2, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'iqiyi': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'issue': {'count': 4,
#            'src': {'58f831913f3dfa243452d7ee_12',
#                    '58f831913f3dfa243452d7ee_2',
#                    '58f831913f3dfa243452d7ee_4',
#                    '58f831913f3dfa243452d7ee_8'}},
#  'jiang': {'count': 2,
#            'src': {'58f831913f3dfa243452d7ee_14',
#                    '58f831913f3dfa243452d7ee_15'}},
#  'july': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'junior': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'korean': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'language': {'count': 2,
#               'src': {'58f831913f3dfa243452d7ee_14',
#                       '58f831913f3dfa243452d7ee_16'}},
#  'large': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'last': {'count': 2,
#           'src': {'58f831913f3dfa243452d7ee_12', '58f831913f3dfa243452d7ee_4'}},
#  'latest': {'count': 3,
#             'src': {'58f831913f3dfa243452d7ee_4',
#                     '58f831913f3dfa243452d7ee_5',
#                     '58f831913f3dfa243452d7ee_6'}},
#  'lead': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'like': {'count': 3,
#           'src': {'58f831913f3dfa243452d7ee_11',
#                   '58f831913f3dfa243452d7ee_5',
#                   '58f831913f3dfa243452d7ee_6'}},
#  'line': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'liu': {'count': 2,
#          'src': {'58f831913f3dfa243452d7ee_18', '58f831913f3dfa243452d7ee_7'}},
#  'longer': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_1'}},
#  'love': {'count': 2,
#           'src': {'58f831913f3dfa243452d7ee_18',
#                   '58f831913f3dfa243452d7ee_19'}},
#  'lucrative': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'make': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'management': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'march': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'mass': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'masterchef': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'meal': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'medium': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'might': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'million': {'count': 2, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'ming': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'minor': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_13'}},
#  'monday': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_14',
#                     '58f831913f3dfa243452d7ee_15'}},
#  'month': {'count': 3,
#            'src': {'58f831913f3dfa243452d7ee_12',
#                    '58f831913f3dfa243452d7ee_17',
#                    '58f831913f3dfa243452d7ee_4'}},
#  'mouthpiece': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_18'}},
#  'much': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_13'}},
#  'multiple': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'name': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'negative': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_10'}},
#  'new': {'count': 6,
#          'src': {'58f831913f3dfa243452d7ee_11',
#                  '58f831913f3dfa243452d7ee_12',
#                  '58f831913f3dfa243452d7ee_2',
#                  '58f831913f3dfa243452d7ee_4',
#                  '58f831913f3dfa243452d7ee_8'}},
#  'news': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_3'}},
#  'newspaper': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'nickname': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'notice': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'october': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'official': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_18'}},
#  'one': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'ones': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_19'}},
#  'online': {'count': 4,
#             'src': {'58f831913f3dfa243452d7ee_11',
#                     '58f831913f3dfa243452d7ee_14',
#                     '58f831913f3dfa243452d7ee_16',
#                     '58f831913f3dfa243452d7ee_4'}},
#  'organization': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'outline': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'overly': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'overnight': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_3'}},
#  'own': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'papus': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'parent': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'participate': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_2'}},
#  'pay': {'count': 2,
#          'src': {'58f831913f3dfa243452d7ee_12', '58f831913f3dfa243452d7ee_16'}},
#  'people': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_14',
#                     '58f831913f3dfa243452d7ee_18'}},
#  'person': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_19',
#                     '58f831913f3dfa243452d7ee_8'}},
#  'personality': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'pitfall': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_3'}},
#  'place': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_18'}},
#  'player': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'policy': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'popular': {'count': 2,
#              'src': {'58f831913f3dfa243452d7ee_14',
#                      '58f831913f3dfa243452d7ee_5'}},
#  'positive': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'possible': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_13'}},
#  'post': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_15'}},
#  'praise': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_18'}},
#  'premiere': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'pres': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_2'}},
#  'producer': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_8'}},
#  'production': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'program': {'count': 4,
#              'src': {'58f831913f3dfa243452d7ee_11',
#                      '58f831913f3dfa243452d7ee_13',
#                      '58f831913f3dfa243452d7ee_14',
#                      '58f831913f3dfa243452d7ee_7'}},
#  'prone': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_1'}},
#  'protect': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_3'}},
#  'public': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_12',
#                     '58f831913f3dfa243452d7ee_15'}},
#  'publication': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_2'}},
#  'publish': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_18'}},
#  'radio': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_2'}},
#  'reality': {'count': 7,
#              'src': {'58f831913f3dfa243452d7ee_1',
#                      '58f831913f3dfa243452d7ee_12',
#                      '58f831913f3dfa243452d7ee_13',
#                      '58f831913f3dfa243452d7ee_14',
#                      '58f831913f3dfa243452d7ee_2',
#                      '58f831913f3dfa243452d7ee_8'}},
#  'receive': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'recent': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_17',
#                     '58f831913f3dfa243452d7ee_7'}},
#  'rectify': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'reform': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'regulation': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'regulator': {'count': 6,
#                'src': {'58f831913f3dfa243452d7ee_1',
#                        '58f831913f3dfa243452d7ee_12',
#                        '58f831913f3dfa243452d7ee_14',
#                        '58f831913f3dfa243452d7ee_8'}},
#  'rein': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'reincarnation': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'relationship': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'report': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_14',
#                     '58f831913f3dfa243452d7ee_3'}},
#  'requirement': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'research': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_20'}},
#  'resolutely': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'respond': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'response': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_15'}},
#  'restriction': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'return': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_19'}},
#  'revenue': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'reversal': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_17'}},
#  'romance': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'rule': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'run': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_3'}},
#  'rural': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'sanction': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'satirical': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'say': {'count': 6,
#          'src': {'58f831913f3dfa243452d7ee_11',
#                  '58f831913f3dfa243452d7ee_13',
#                  '58f831913f3dfa243452d7ee_3',
#                  '58f831913f3dfa243452d7ee_5',
#                  '58f831913f3dfa243452d7ee_8'}},
#  'scope': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'scrutiny': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'season': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_6',
#                     '58f831913f3dfa243452d7ee_7'}},
#  'see': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_8'}},
#  'several': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'show': {'count': 12,
#           'src': {'58f831913f3dfa243452d7ee_11',
#                   '58f831913f3dfa243452d7ee_12',
#                   '58f831913f3dfa243452d7ee_18',
#                   '58f831913f3dfa243452d7ee_19',
#                   '58f831913f3dfa243452d7ee_2',
#                   '58f831913f3dfa243452d7ee_5',
#                   '58f831913f3dfa243452d7ee_6',
#                   '58f831913f3dfa243452d7ee_7',
#                   '58f831913f3dfa243452d7ee_9'}},
#  'smoke': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'social': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_10'}},
#  'socialist': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'something': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_17'}},
#  'south': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'specifically': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_5'}},
#  'specify': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'spinoff': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'start': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_10'}},
#  'state': {'count': 4,
#            'src': {'58f831913f3dfa243452d7ee_14',
#                    '58f831913f3dfa243452d7ee_2',
#                    '58f831913f3dfa243452d7ee_3',
#                    '58f831913f3dfa243452d7ee_4'}},
#  'still': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_17'}},
#  'stream': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'sunday': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_3'}},
#  'take': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'tantrum': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_1'}},
#  'task': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'television': {'count': 10,
#                 'src': {'58f831913f3dfa243452d7ee_1',
#                         '58f831913f3dfa243452d7ee_12',
#                         '58f831913f3dfa243452d7ee_14',
#                         '58f831913f3dfa243452d7ee_2',
#                         '58f831913f3dfa243452d7ee_4',
#                         '58f831913f3dfa243452d7ee_5',
#                         '58f831913f3dfa243452d7ee_6',
#                         '58f831913f3dfa243452d7ee_8'}},
#  'tendency': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'thi': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_10'}},
#  'think': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_8'}},
#  'third': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'top': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_1'}},
#  'toward': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_17'}},
#  'transfer': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'travel': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'two': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'underage': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'use': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'value': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_12'}},
#  'video': {'count': 3,
#            'src': {'58f831913f3dfa243452d7ee_14',
#                    '58f831913f3dfa243452d7ee_16'}},
#  'viewer': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_6'}},
#  'viral': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'vulgar': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_14'}},
#  'want': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_8'}},
#  'website': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_11'}},
#  'wechat': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_15'}},
#  'witchcraft': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_4'}},
#  'worker': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'write': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_16'}},
#  'xinhua': {'count': 2,
#             'src': {'58f831913f3dfa243452d7ee_11',
#                     '58f831913f3dfa243452d7ee_3'}},
#  'xue': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_8'}},
#  'xuejie': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_20'}},
#  'yang': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_18'}},
#  'yao': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_7'}},
#  'zhao': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_20'}},
#  'zhejiang': {'count': 1, 'src': {'58f831913f3dfa243452d7ee_5'}}}

# %%
json.dump(newdict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-211e05075d09> in <module>()
# ----> 1 collection_write.insert_many(json.dump(newdict))
#
# TypeError: dump() missing 1 required positional argument: 'fp'

# %%
# 斷詞、計次、紀錄來源段落

def updateWordsDict(collectionFind, words_dict):
    
    contents = collectionFind['content']
    art_id = collectionFind['_id']
# words_dict = {}

# [for DEBUG]
# wordlist=[]

    for numPara in range(len(contents)):
        para_id = str(numPara + 1)
        para_wds = str(TextBlob(contents[para_id]).words.lower().singularize())
    #     words = str(Word(para_wds).lemmatize("v"))

        match = re.findall('[a-z]+', para_wds)

        for word in match:
            if word not in stoplist and len(word)>2:

    #             [for DEBUG]
    #             wordlist.append('%s from %s'%(word, para_id))

                # Lemmatizing verb. to present tense
                wd = Word(word).lemmatize("v")

                if wd not in words_dict:
                    src_list = set(['%s_%s'%(art_id, para_id)])
                    word_info = {}
                    word_info['count'] = 1
                    word_info['src'] = src_list
                    words_dict[wd] = word_info
                else:
                    words_dict[wd]['count'] += 1
                    words_dict[wd]['src'].add('%s_%s'%(art_id, para_id))
            
# pprint(words_dict)
    return words_dict

# %%
wordlist.sort()

# %%
text = "Activity is good Enegry."
a = textblob.TextBlob(text)
a.words

# %%
wordlist

# %%
para = tb(content['1'])
para2 = tb(content['2'])
# give a tag for each word
para.tags
# get noun phrases from text
para.noun_phrases
# get single word
para.words
# count
para.word_counts
# # get single sentences
# print(para2.sentences)
# # objective(0.0), subjective(1.0)
# para2.sentences[2].sentiment.polarity
# test = 'I like python so much!'
# tb(test).sentiment.polarity
